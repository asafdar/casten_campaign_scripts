# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'cfc1.csv')
df2 = pd.read_csv(r'cfc2.csv')
df3 = pd.read_csv(r'cfc3.csv')
df4 = pd.read_csv(r'cfc4.csv')
df5 = pd.read_csv(r'cfc5.csv')
df6 = pd.read_csv(r'cfc6.csv')
df7 = pd.read_csv(r'cfc7.csv')
df8 = pd.read_csv(r'cfc8.csv')
df9 = pd.read_csv(r'cfc9.csv')
# Out:
# /home/ahmed.safdar/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (52) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/ahmed.safdar/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/ahmed.safdar/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (11,16,28,45,50,51,54,61,63,71,72,73,74,75) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
df1.head()
# Out:
#    CanvassFileRequestID    VanID           Phone  PhoneDialingPrefix  \
# 0                  4279  1546567  (608) 332-8851                   1
# 1                  4279  1702274  (847) 867-0136                   1
# 2                  4279  1734363  (847) 840-7362                   1
# 3                  4279  1743731  (847) 767-7657                   1
# 4                  4279  1744625  (847) 962-3691                   1
#
#   PhoneCountryCode State                                            Address  \
# 0               US    IL        4270 Portage Ln , Hoffman Estates, IL 60192
# 1               US    IL  1312 Rolling Prairie Ct , Hoffman Estates, IL ...
# 2               US    IL          4566 Topaz Dr , Hoffman Estates, IL 60192
# 3               US    IL   1200 W Sturbridge Dr , Hoffman Estates, IL 60192
# 4               US    IL   4190 N Sturbridge Dr , Hoffman Estates, IL 60192
#
#   FirstName LastName             StreetAddress  ... aC2020-09-16  \
# ...

# %%
df1.shape
# Out:
# (55584, 56)

# %%
df1 = df1[df1['R4'].notna()]

# %%
df1.shape
# Out:
# (55, 56)

# %%
df1.head()
# Out:
#        CanvassFileRequestID     VanID           Phone  PhoneDialingPrefix  \
# 9175                   4279  19215338  (773) 764-1400                   1
# 9490                   4279   4003575  (630) 653-3001                   1
# 9710                   4279   6818166  (630) 653-3429                   1
# 9939                   4279   2285413  (630) 837-5890                   1
# 11106                  4279   5584224  (630) 231-1478                   1
#
#       PhoneCountryCode State                                    Address  \
# 9175                US    IL          704 Skye Ln , Inverness, IL 60010
# 9490                US    IL      1721 E Indiana St , Wheaton, IL 60187
# 9710                US    IL        945 Kingston St , Wheaton, IL 60187
# 9939                US    IL     950 Bryn Mawr Ave , Bartlett, IL 60103
# 11106               US    IL  146 Ingalton Ave , West Chicago, IL 60185
#
#        FirstName LastName       StreetAddress  ... aC2020-09-16  aC2020-09-17  \
# ...

# %%
df1.reset_index(inplace = True, drop = True)

# %%
df1.head()
# Out:
#    CanvassFileRequestID     VanID           Phone  PhoneDialingPrefix  \
# 0                  4279  19215338  (773) 764-1400                   1
# 1                  4279   4003575  (630) 653-3001                   1
# 2                  4279   6818166  (630) 653-3429                   1
# 3                  4279   2285413  (630) 837-5890                   1
# 4                  4279   5584224  (630) 231-1478                   1
#
#   PhoneCountryCode State                                    Address  \
# 0               US    IL          704 Skye Ln , Inverness, IL 60010
# 1               US    IL      1721 E Indiana St , Wheaton, IL 60187
# 2               US    IL        945 Kingston St , Wheaton, IL 60187
# 3               US    IL     950 Bryn Mawr Ave , Bartlett, IL 60103
# 4               US    IL  146 Ingalton Ave , West Chicago, IL 60185
#
#    FirstName LastName       StreetAddress  ... aC2020-09-16  aC2020-09-17  \
# ...

# %%
df2 = df2[df2['R4'].notna()]
df3 = df3[df3['R4'].notna()]
df4 = df4[df4['R4'].notna()]
df5 = df5[df5['R5'].notna()]
df6 = df6[df6['R4'].notna()]
df7 = df7[df7['R4'].notna()]
df8 = df8[df8['R4'].notna()]
df9 = df9[df9['R4'].notna()]

# %%
df2.reset_index(inplace = True, drop = True)
df3.reset_index(inplace = True, drop = True)
df4.reset_index(inplace = True, drop = True)
df5.reset_index(inplace = True, drop = True)
df6.reset_index(inplace = True, drop = True)
df7.reset_index(inplace = True, drop = True)
df8.reset_index(inplace = True, drop = True)
df9.reset_index(inplace = True, drop = True)

# %%
df1.to_csv('cfc1_modified.csv')
df2.to_csv('cfc2_modified.csv')
df3.to_csv('cfc3_modified.csv')
df4.to_csv('cfc4_modified.csv')
df5.to_csv('cfc5_modified.csv')
df6.to_csv('cfc6_modified.csv')
df7.to_csv('cfc7_modified.csv')
df8.to_csv('cfc8_modified.csv')
df9.to_csv('cfc9_modified.csv')
